# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import ShuffleSplit
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import matplotlib.style as style
style.use('fivethirtyeight')

# %%
orders = pd.read_csv('Orders.csv',index_col='Row.ID',
                     parse_dates=['Order.Date','Ship.Date'])

returns = pd. read_csv("Returns.csv")

# %%
print(orders.shape)
print(returns.shape)
# Out:
# (51290, 23)
# (1079, 3)

# %%
orders.columns.to_list()
# Out:
# ['Order.ID',
#  'Order.Date',
#  'Ship.Date',
#  'Ship.Mode',
#  'Customer.ID',
#  'Customer.Name',
#  'Segment',
#  'Postal.Code',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Market',
#  'Product.ID',
#  'Category',
#  'Sub.Category',
#  'Product.Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping.Cost',
#  'Order.Priority']

# %%
orders = orders.astype({'Sales':'string', 'Profit':'string'})

# %%
orders['Sales'] = orders.apply(lambda x: x['Sales'].replace('$',''), axis = 1)

# %%
orders['Profit'] = orders.apply(lambda x: x['Profit'].replace('$',''), axis = 1)

# %%
orders['Sales'] = orders.apply(lambda x: x['Sales'].replace(',',''), axis = 1)
orders['Profit'] = orders.apply(lambda x: x['Profit'].replace(',',''), axis = 1)

# %%
orders.astype({'Sales':'float64', 'Profit':'float64'})
# Out:
#                         Order.ID Order.Date  Ship.Date       Ship.Mode  \
# Row.ID
# 40098   CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 26341     IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 25330     IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 13524    ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 47221    SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                          ...        ...        ...             ...
# 29002    IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 34337   US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 31315   CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 9596     MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 6147     MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#          Customer.ID       Customer.Name      Segment  Postal.Code  \
# Row.ID
# 40098   AB-100151402       Aaron Bergman     Consumer      73120.0
# 26341      JR-162107       Justin Ritter    Corporate          NaN
# 25330      CR-127307        Craig Reiter     Consumer          NaN
# 13524     KM-1637548    Katherine Murray  Home Office          NaN
# 47221     RH-9495111         Rick Hansen     Consumer          NaN
# ...              ...                 ...          ...          ...
# 29002     KE-1642066     Katrina Edelman    Corporate          NaN
# 34337   ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 31315   ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 9596      RB-1979518          Ross Baird  Home Office          NaN
# 6147      MC-1810093       Mick Crebagga     Consumer          NaN
#
#                  City            State  ...   Product.ID         Category  \
# Row.ID                                  ...
# 40098   Oklahoma City         Oklahoma  ...  TEC-PH-5816       Technology
# 26341      Wollongong  New South Wales  ...  FUR-CH-5379        Furniture
# 25330        Brisbane       Queensland  ...  TEC-PH-5356       Technology
# 13524          Berlin           Berlin  ...  TEC-PH-5267       Technology
# 47221           Dakar            Dakar  ...  TEC-CO-6011       Technology
# ...               ...              ...  ...          ...              ...
# 29002            Kure        Hiroshima  ...  OFF-FA-3072  Office Supplies
# 34337     Chattanooga        Tennessee  ...  FUR-FU-4070        Furniture
# 31315   San Francisco       California  ...  OFF-AR-5321  Office Supplies
# 9596         Valinhos        São Paulo  ...  OFF-BI-2919  Office Supplies
# 6147         Tipitapa          Managua  ...  OFF-PA-3990  Office Supplies
#
#        Sub.Category                                   Product.Name    Sales  \
# Row.ID
# 40098        Phones                               Samsung Convoy 3   221.98
# 26341        Chairs      Novimex Executive Leather Armchair, Black  3709.40
# 25330        Phones              Nokia Smart Phone, with Caller ID  5175.17
# 13524        Phones                 Motorola Smart Phone, Cordless  2892.51
# 47221       Copiers                 Sharp Wireless Fax, High-Speed  2832.96
# ...             ...                                            ...      ...
# 29002     Fasteners                  Advantus Thumb Tacks, 12 Pack    65.10
# 34337   Furnishings  Eldon Image Series Desk Accessories, Burgundy    16.72
# 31315           Art                                     Newell 341     8.56
# 9596        Binders                        Acco Index Tab, Economy    13.44
# 6147          Paper        Eaton Computer Printout Paper, 8.5 x 11    61.38
#
#        Quantity Discount  Profit  Shipping.Cost  Order.Priority
# Row.ID
# 40098         2      0.0   62.15         40.770            High
# 26341         9      0.1 -288.77        923.630        Critical
# 25330         9      0.1  919.97        915.490          Medium
# 13524         5      0.1  -96.54        910.160          Medium
# 47221         8      0.0  311.52        903.040        Critical
# ...         ...      ...     ...            ...             ...
# 29002         5      0.0    4.50          1.010          Medium
# 34337         5      0.2    3.34          1.930            High
# 31315         2      0.0    2.48          1.580            High
# 9596          2      0.0    2.40          1.003          Medium
# 6147          3      0.0    1.80          1.002            High
#
# [51290 rows x 23 columns]

# %%
orders.loc[:,['Order.ID', 'Order.Date', 'Product.ID',
 'Category',
 'Sub.Category',
 'Product.Name',
 'Sales',
 'Quantity',
 'Discount',
 'Profit',]].head(10)
# Out:
#                         Order.ID Order.Date   Product.ID    Category  \
# Row.ID
# 40098   CA-2014-AB10015140-41954 2014-11-11  TEC-PH-5816  Technology
# 26341     IN-2014-JR162107-41675 2014-02-05  FUR-CH-5379   Furniture
# 25330     IN-2014-CR127307-41929 2014-10-17  TEC-PH-5356  Technology
# 13524    ES-2014-KM1637548-41667 2014-01-28  TEC-PH-5267  Technology
# 47221    SG-2014-RH9495111-41948 2014-11-05  TEC-CO-6011  Technology
# 22732     IN-2014-JM156557-41818 2014-06-28  TEC-PH-5842  Technology
# 30570    IN-2012-TS2134092-41219 2012-11-06  FUR-CH-5378   Furniture
# 31192    IN-2013-MB1808592-41378 2013-04-14  FUR-TA-3764   Furniture
# 40099   CA-2014-AB10015140-41954 2014-11-11  FUR-BO-5957   Furniture
# 36258   CA-2012-AB10015140-40974 2012-03-06  FUR-CH-4421   Furniture
#
#        Sub.Category                                       Product.Name  \
# Row.ID
# 40098        Phones                                   Samsung Convoy 3
# 26341        Chairs          Novimex Executive Leather Armchair, Black
# 25330        Phones                  Nokia Smart Phone, with Caller ID
# 13524        Phones                     Motorola Smart Phone, Cordless
# 47221       Copiers                     Sharp Wireless Fax, High-Speed
# 22732        Phones                Samsung Smart Phone, with Caller ID
# 30570        Chairs     Novimex Executive Leather Armchair, Adjustable
# 31192        Tables       Chromcraft Conference Table, Fully Assembled
# 40099     Bookcases  Sauder Facets Collection Library, Sky Alder Fi...
# 36258        Chairs         Global Push Button Manager's Chair, Indigo
#
#           Sales  Quantity  Discount   Profit
# Row.ID
# 40098    221.98         2       0.0    62.15
# 26341   3709.40         9       0.1  -288.77
# 25330   5175.17         9       0.1   919.97
# 13524   2892.51         5       0.1   -96.54
# 47221   2832.96         8       0.0   311.52
# 22732   2862.68         5       0.1   763.28
# 30570   1822.08         4       0.0   564.84
# 31192   5244.84         6       0.0   996.48
# 40099    341.96         2       0.0    54.71
# 36258     48.71         1       0.2     5.48

# %%
orders['Order.Yr'] = orders.apply(lambda x: x['Order.Date'].year, axis=1)
orders['Order.Mnth'] = orders.apply(lambda x: x['Order.Date'].month, axis=1)

# %%
orders.dtypes
# Out:
# Order.ID                  object
# Order.Date        datetime64[ns]
# Ship.Date         datetime64[ns]
# Ship.Mode                 object
# Customer.ID               object
# Customer.Name             object
# Segment                   object
# Postal.Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product.ID                object
# Category                  object
# Sub.Category              object
# Product.Name              object
# Sales                     object
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping.Cost            float64
# Order.Priority            object
# Order.Yr                   int64
# Order.Mnth                 int64
# dtype: object

# %%
# months = [f'{m[0]}-{m[1]}'for m in list(orders.groupby(['Order.Yr', 'Order.Mnth']).sum().loc[:,['Sales', 'Quantity']].index)]

# %%
# x = months
# y = orders.groupby(['Order.Yr', 'Order.Mnth']).sum().loc[:,['Sales', 'Quantity']]['Sales']
# _ = sns.lineplot(x=x,y=y)
# _.tick_params(axis='x', rotation=90, labelsize=7)
# plt.show()

# %%
# x = months
# y = orders.groupby(['Order.Yr', 'Order.Mnth']).sum().loc[:,['Sales', 'Quantity']]['Quantity']
# _ = sns.lineplot(x=x,y=y)
# _.tick_params(axis='x', rotation=90, labelsize=7)
# plt.show()

# %%
# bycat_data = orders.groupby(['Order.Yr', 'Order.Mnth', 'Category']).sum().loc[:,['Sales', 'Quantity']].reset_index()
# sns.lineplot(data=bycat_data, x = 'Order.Mnth', y='Sales', hue='Category')

# %%
# bycat_data = orders.groupby(['Order.Yr', 'Order.Mnth', 'Category']).sum().loc[:,['Sales', 'Quantity']].reset_index()
# sns.lineplot(data=bycat_data, x = 'Order.Mnth', y='Quantity', hue='Category')

# %%
returns.columns.to_list()
# Out:
# ['Returned', 'Order ID', 'Region']

# %%
OR_merge = orders.merge(returns, how='left', left_on='Order.ID', right_on='Order ID')
OR_merge.head()
# Out:
#                    Order.ID Order.Date  Ship.Date     Ship.Mode   Customer.ID  \
# 0  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class  AB-100151402
# 1    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class     JR-162107
# 2    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class     CR-127307
# 3   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class    KM-1637548
# 4   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day    RH-9495111
#
#       Customer.Name      Segment  Postal.Code           City            State  \
# 0     Aaron Bergman     Consumer      73120.0  Oklahoma City         Oklahoma
# 1     Justin Ritter    Corporate          NaN     Wollongong  New South Wales
# 2      Craig Reiter     Consumer          NaN       Brisbane       Queensland
# 3  Katherine Murray  Home Office          NaN         Berlin           Berlin
# 4       Rick Hansen     Consumer          NaN          Dakar            Dakar
#
#    ... Quantity Discount   Profit Shipping.Cost Order.Priority Order.Yr  \
# 0  ...        2      0.0    62.15         40.77           High     2014
# 1  ...        9      0.1  -288.77        923.63       Critical     2014
# 2  ...        9      0.1   919.97        915.49         Medium     2014
# 3  ...        5      0.1   -96.54        910.16         Medium     2014
# 4  ...        8      0.0   311.52        903.04       Critical     2014
#
#   Order.Mnth Returned  Order ID  Region_y
# 0         11      NaN       NaN       NaN
# 1          2      NaN       NaN       NaN
# 2         10      NaN       NaN       NaN
# 3          1      NaN       NaN       NaN
# 4         11      NaN       NaN       NaN
#
# [5 rows x 28 columns]

# %%
OR_merge.shape
# Out:
# (51290, 28)

# %%
OR_merge.isna().sum()
# Out:
# Order.ID              0
# Order.Date            0
# Ship.Date             0
# Ship.Mode             0
# Customer.ID           0
# Customer.Name         0
# Segment               0
# Postal.Code       41296
# City                  0
# State                 0
# Country               0
# Region_x              0
# Market                0
# Product.ID            0
# Category              0
# Sub.Category          0
# Product.Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping.Cost         0
# Order.Priority        0
# Order.Yr              0
# Order.Mnth            0
# Returned          49070
# Order ID          49070
# Region_y          49070
# dtype: int64

# %%
OR_merge.loc[OR_merge['Returned'].isna(),'return_flag'] = 0
OR_merge.loc[~OR_merge['Returned'].isna(),'return_flag'] = 1

# %%
OR_merge.dtypes
# Out:
# Order.ID                  object
# Order.Date        datetime64[ns]
# Ship.Date         datetime64[ns]
# Ship.Mode                 object
# Customer.ID               object
# Customer.Name             object
# Segment                   object
# Postal.Code              float64
# City                      object
# State                     object
# Country                   object
# Region_x                  object
# Market                    object
# Product.ID                object
# Category                  object
# Sub.Category              object
# Product.Name              object
# Sales                     object
# Quantity                   int64
# Discount                 float64
# Profit                    object
# Shipping.Cost            float64
# Order.Priority            object
# Order.Yr                   int64
# Order.Mnth                 int64
# Returned                  object
# Order ID                  object
# Region_y                  object
# return_flag              float64
# dtype: object

# %%
OR_merge.groupby('return_flag').sum()
# Out:
#              Postal.Code  Quantity  Discount  Shipping.Cost  Order.Yr  \
# return_flag
# 0.0          525128350.0    170637  7003.200   1.297243e+06  98816106
# 1.0           26444302.0      7675   326.528   6.084260e+04   4470527
#
#              Order.Mnth
# return_flag
# 0.0              368448
# 1.0               17049

# %%
OR_merge.groupby('return_flag').sum()['Profit']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-90d2ca24d654> in <module>
# ----> 1 OR_merge.groupby('return_flag').sum()['Profit']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Profit'

# %%
ret_cnt = OR_merge.groupby('Customer.ID').sum()['return_flag']

# %%
sum(ret_cnt > 1)

# %%
sum(ret_cnt > 5)

# %%
OR_merge.dtypes

# %%
OR_merge['process_time'] = OR_merge['Ship.Date'] - OR_merge['Order.Date']
OR_merge.groupby(['return_flag']).agg({'process_time':'mean'})
